# %% [markdown]
# #### Using Matplotlib

# %%
import matplotlib.pyplot as plt
x=list(range(-80,80))
y=[i**2 for i in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# #### File ####

# %%
fd=open('first_file.txt','w') #Ket noi voi file, ghi de
text_1 ='Nhung danng yeu' 
fd.write(text_1) #Ghi noi dung vao file
fd.close() #Dong ket noi voi file

# %%
# Out:
# 19
